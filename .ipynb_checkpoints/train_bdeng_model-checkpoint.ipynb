# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) 
import numpy as np
import os
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import h5py
import glob
import random
import time
import tensorflow as tf
import datetime

# %% [markdown]
# # Create model

# %%
from temporal_3d_general import *

def vae_loss(x, t_decoded):
    '''Total loss for the plain UAE'''
    return K.mean(reconstruction_loss(x, t_decoded))

def reconstruction_loss(x, t_decoded):
    '''Reconstruction loss for the plain UAE'''
    return K.sum((K.batch_flatten(x) - K.batch_flatten(t_decoded)) ** 2, axis=-1)

input_shape=(96, 200, 24 ,3)
vae_model = create_vae(input_shape)
vae_model.summary()
output_dir = 'saved_models/'
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              (None, 96, 200, 24,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 48, 100, 12,  1312        image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 48, 100, 12,  64          conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 100, 12,  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 48, 100, 12,  13856       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 100, 12,  128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 100, 12,  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 24, 50, 6, 64 55360       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 24, 50, 6, 64 256         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 50, 6, 64 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 24, 50, 6, 64 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 24, 50, 6, 64 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 50, 6, 64 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 12, 25, 3, 12 221312      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 12, 25, 3, 12 512         conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 12, 25, 3, 12 442496      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 12, 25, 3, 12 512         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 12, 25, 3, 12 442496      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 12, 25, 3, 12 512         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 12, 25, 3, 12 442496      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 12, 25, 3, 12 512         conv3d_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 12, 25, 3, 12 0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 12, 25, 3, 12 442496      add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 12, 25, 3, 12 512         conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 12, 25, 3, 12 442496      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 25, 3, 12 512         conv3d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 25, 3, 12 0           add[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 12, 25, 3, 12 442496      add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 25, 3, 12 512         conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 12, 25, 3, 12 442496      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 12, 25, 3, 12 512         conv3d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 12, 25, 3, 12 0           add_1[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 12, 25, 3, 12 442496      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 25, 3, 12 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 25, 3, 12 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 12, 25, 3, 12 442496      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 25, 3, 12 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 12, 25, 3, 12 0           add_2[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 12, 25, 3, 12 442496      add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 12, 25, 3, 12 512         conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 25, 3, 12 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 12, 25, 3, 12 442496      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 12, 25, 3, 12 512         conv3d_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 25, 3, 12 0           add_3[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 12, 25, 3, 12 442496      add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 25, 3, 12 512         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 25, 3, 12 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 12, 25, 3, 12 442496      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 25, 3, 12 512         conv3d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 25, 3, 12 0           add_4[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 12, 25, 3, 12 442496      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 25, 3, 12 512         conv3d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 25, 3, 12 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 12, 25, 3, 12 442496      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 25, 3, 12 512         conv3d_19[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 25, 3, 12 0           add_5[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 12, 25, 3, 12 0           add_6[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d (Reflectio (None, 14, 27, 5, 12 0           up_sampling3d[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 12, 25, 3, 12 442496      reflection_padding3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 25, 3, 12 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 25, 3, 12 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 24, 50, 6, 12 0           activation_13[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d_1 (Reflect (None, 26, 52, 8, 12 0           up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 24, 50, 6, 12 442496      reflection_padding3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 24, 50, 6, 12 512         conv3d_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 50, 6, 12 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 24, 50, 6, 12 0           activation_14[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d_2 (Reflect (None, 26, 52, 8, 12 0           up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 24, 50, 6, 64 221248      reflection_padding3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 24, 50, 6, 64 256         conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 50, 6, 64 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 48, 100, 12,  0           activation_15[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d_3 (Reflect (None, 50, 102, 14,  0           up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 48, 100, 12,  110656      reflection_padding3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 48, 100, 12,  256         conv3d_23[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 48, 100, 12,  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 48, 100, 12,  0           activation_16[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d_4 (Reflect (None, 50, 102, 14,  0           up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 48, 100, 12,  55328       reflection_padding3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 48, 100, 12,  128         conv3d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 48, 100, 12,  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)  (None, 96, 200, 24,  0           activation_17[0][0]
# __________________________________________________________________________________________________
# reflection_padding3d_5 (Reflect (None, 98, 202, 26,  0           up_sampling3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 96, 200, 24,  13840       reflection_padding3d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 96, 200, 24,  64          conv3d_25[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 96, 200, 24,  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 96, 200, 24,  433         activation_18[0][0]
# ==================================================================================================
# Total params: 8,337,057
# Trainable params: 8,331,745
# Non-trainable params: 5,312
# __________________________________________________________________________________________________

# %% [markdown]
# # Load data set

# %%
def load_data(name):
    hf_r = h5py.File(f'/data/cees/gegewen/CCSNet_publish_dataset/{name}.hdf5', 'r')
    variable = np.array(hf_r.get(name))
    hf_r.close()
    return variable

def create_x(train_input, train_BPR, train_BYMF):
    data_x_BPR = (train_BPR - 100)/(565 - 100)
    data_x_temp = np.repeat(train_input[:,:,:,-4,:][:,:,:,np.newaxis,:], 24, axis=-2)
    return np.concatenate([data_x_temp, data_x_BPR, train_BYMF], axis=-1)

# %%
train_x = create_x(load_data('train_x'), load_data('train_y_BPR'), load_data('train_y_BYMF'))
train_x[:,:,:,:,-1][train_x[:,:,:,:,-1]==0] = 0.9 # Clipping for normalization
train_x[:,:,:,:,-1] = (train_x[:,:,:,:,-1] - 0.9)/0.1 # Normalization
train_y = load_data('train_y_BDENG')
train_y[train_y==0] = 100 # Clipping for normalization
train_y = (train_y - 100) / 900 # Normalization

# %%
test_x = create_x(load_data('test_x'), load_data('test_y_BPR'), load_data('test_y_BYMF'))
test_x[:,:,:,:,-1][test_x[:,:,:,:,-1]==0] = 0.9 # Clipping for normalization
test_x[:,:,:,:,-1] = (test_x[:,:,:,:,-1] - 0.9)/0.1 # Normalization
test_y = load_data('test_y_BDENG')
test_y[test_y==0] = 100 # Clipping for normalization
test_y = (test_y - 100) / 900 # Normalization

# %%
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)

# %%
# Random shuffle
np.random.seed(0)
train_nr = train_x.shape[0]
train_shuffle_index = np.random.choice(train_nr, train_nr, replace=False)
print(train_shuffle_index.shape)

test_nr = test_x.shape[0]
test_shuffle_index = np.random.choice(test_nr, test_nr, replace=False)
print(test_shuffle_index.shape)

train_x = train_x[train_shuffle_index, ...]
train_y = train_y[train_shuffle_index, ...]
test_x = test_x[test_shuffle_index, ...]
test_y = test_y[test_shuffle_index, ...]

print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape is ', test_x.shape)
print('test_y shape is ', test_y.shape)

# %% [markdown]
# # Training
#
# *Note: gradually reduce learning rate from 1e-4 to 1e-7 as you train*

# %%
train_nr = train_x.shape[0]
batch_size = 8
num_batch = int(train_nr/batch_size)
test_nr = 8
e_start = 0
epoch = 1000
learning_rate = 1e-4

opt = Adam(lr=learning_rate)

train_target = K.placeholder(shape=(batch_size, 96, 200, 24 ,1))
test_target = K.placeholder(shape=(test_nr, 96, 200, 24 ,1))

rec_loss = vae_loss(vae_model.output, train_target)
vae_model.compile(loss=vae_loss, optimizer=opt)

total_loss = rec_loss

updates = opt.get_updates(total_loss, vae_model.trainable_weights)

iterate = K.function(vae_model.inputs + [train_target], [rec_loss], updates=updates)

eval_rec_loss = vae_loss(vae_model.output, test_target)

evaluate = K.function(vae_model.inputs + [test_target], [eval_rec_loss])

model_string = 'bdeng'

# %%
for e in range(e_start, e_start + epoch):
    for ib in range(num_batch):
        ind0 = ib * batch_size        
        x_batch = train_x[ind0:ind0+batch_size, ...]
        y_batch = train_y[ind0:ind0+batch_size, ...]
        rec_loss_val = iterate([x_batch] + [y_batch])
        
        if ib % 100 == 0:
            print('Epoch %d/%d, Batch %d/%d, Rec Loss %f' % (e+1, epoch, ib+1, num_batch, rec_loss_val[0]))
            
    eval_rec_loss_val = evaluate([test_x[:4,...]] + [test_y[:4,...]])
    print('Epoch %d/%d, Train Rec loss %f, Eval Rec loss %f' % (e + 1, epoch, rec_loss_val[0], eval_rec_loss_val[0]))
    
    if (e+1) % 5 == 0:
        vae_model.save_weights(output_dir + model_string + '_%dtrain_lr%f_ep%d.h5' % (train_nr, learning_rate, (e + 1)))

vae_model.save_weights(output_dir + model_string + '_%dtrain_lr%f_ep%d.h5' % (train_nr, learning_rate, epoch + e_start))
